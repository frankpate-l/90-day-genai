# %%
print(" I did that")
# Out:
#  I did that

# %% [markdown]
# On a Mac, set up your virtual environment outside the project folder to keep things clean. This ensures it runs smoothly. Also, remember to always generate a requirements.txt file.

# %% [markdown]
# python is case sensitive

# %%
name = "naruto"
Name = "luffy"

print(name)
print(Name)
# Out:
# naruto
# luffy

# %%
## Indentation

age=20

if age>18:
    print(age)

print(age)
# Out:
# 20
# 20

# %%
## Line Continuation

total=1+2+3+4+5+6+\
7+8+9

print(total)
# Out:
# 45

# %%
## Multiple Statements on a single line using ';'
x=5;y=10;z=x+y;z=z+z;print(z)
# Out:
# 30

# %%
##Understand  Semnatics

age=21
name="zoro"

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
## Type Inference
variable=10
print(type(variable))
variable="Zoro"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age=32
if age>30:
    print(age)
# Out:
# 32

# %%
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined

# %%
## Code exmaples of indentation
if True:
    print("First Indentation")
    if False:
        print("This ont print")
    print("Outside false")
print("Outside the if")
# Out:
# First Indentation
# Outside false
# Outside the if
