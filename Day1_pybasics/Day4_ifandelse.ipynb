# %% [markdown]
# Conditional Statements

# %%
## if statement
age=21

if age>=21:
    print("you can buy smoke")
else:
    print("you are still kido !!")
# Out:
# you can buy smoke

# %%
## if and else statement
## The else statement executes a block of code if the condition in the if statement is False.
age=18

if age>=21:
    print("you can buy smoke")
else:
    print("you are still kido !!")
# Out:
# you are still kido !!

# %%
## elif 
## it's call "else if" give you two ability to check multiple conditions.

age=19

if age<13:
    print("You are a child")
elif age<18:
    print("You are a teenager")
else:
    print("You are an adult")
# Out:
# You are an adult

# %%
## Nested Condiitonal Statements

## You can place one or more if, elif, or else statements inside another 
# if, elif, or else statement to create nested conditional statements.



num=int(input("Enter the number"))

if num>0:
    print("The number is positive")
    if num%2==0:
        print("The number is even")
    else:
        print("The number is odd")

else:
    print("The number is zero or negative")
# Out:
# The number is positive
# The number is even

# %%
## some example
## Determine if a year is a leap year using nested condition statement

num=int(input("enter year : "))

if num>0:
    if num%4==0:
        if num%100==0:
            if num%400==0:

                print(" yes it is leap year")
            else:
                print(" no it's not leap year")

        else:
            print(" yes it is leap year")

else:
    print(" enter positive num, year not gonna be in negative haha ")
# Out:
#  yes it is leap year

# %%
## Assignment
## Simple Calculator program
# Take user input
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
operation = input("Enter operation (+, -, *, /): ")

# Perform the requested operation
if operation == '+':
    result = num1 + num2
elif operation == '-':
    result = num1 - num2
elif operation == '*':
    result = num1 * num2
elif operation == '/':
    if num2 != 0:
        result = num1 / num2
    else:
        result = "Error! Division by zero."
else:
    result = "Invalid operation."

print("Result:", result)
# Out:
# Result: 47.0

# %%
### Determine the ticket price based on age and whether the person is a student.
# Ticket pricing based on age and student status

age=int(input(" please enter your age : "))
is_student=input(" Are you student? yes or no ").lower()

if age<=5:
    price = " Free "
elif age<18:
    if is_student == "yes":
        price = "$15"
    else:
        price ="$17"
elif age>65:
    if is_student == "yes":
        price = "$15"
    else:
        price ="$17"

else:
    if is_student == "yes":
        price = "$20"
    else:
        price ="$25"
    

print(price)
# Out:
# $25

# %%
""" 
Complex Example 3: Employee Bonus Calculation

Calculate an employee's bonus based on their performance rating and years of service.
"""
## it's boring for me today. I'm gonna do it tomorrow.
# Out:
# " \nComplex Example 3: Employee Bonus Calculation\n\nCalculate an employee's bonus based on their performance rating and years of service.\n"

# %%
# User login system easy pasy hahaha


stored_username = "admin"
stored_password = "password123"


username = input("Enter username: ")
password = input("Enter password: ")


if username == stored_username:
    if password == stored_password:
        print("Login successful!")
    else:
        print("Incorrect password.")
else:
    print("Username not found.")
# Out:
# Login successful!
